# %%
! pip install transformers -q

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, set_seed

# %%
import torch
torch.set_default_tensor_type(torch.cuda.FloatTensor)

# %%
model = AutoModelForCausalLM.from_pretrained("bigscience/bloom-1b7", use_cache=True)
tokenizer = AutoTokenizer.from_pretrained("bigscience/bloom-1b7")

# %%
model.__class__.__name__

# %%
prompt = f'Ending of "darling in the franxx" anime is'

# %%
prompt

# %%
input_ids = tokenizer(prompt, return_tensors="pt").to(0)

# %%
sample = model.generate(**input_ids, max_length=400,  top_k=1, temperature=0.9, repetition_penalty = 2.0)

# %%
print(tokenizer.decode(sample[0], truncate_before_pattern=[r"\n\n^#", "^'''", "\n\n\n"]))
# Out:
# Ending of "darling in the franxx" anime is a bit confusing. The ending was supposed to be "but I don't know if you can see it, but it's not like that at all! It's just...like this? Like what?! But that's okay because I'm going back home now and I'll tell my parents about how much I've enjoyed watching your show!! And then we'll go out for dinner together again so we could talk more!!! So please come over here soon!!!! (I think she said something along those lines)</s>
